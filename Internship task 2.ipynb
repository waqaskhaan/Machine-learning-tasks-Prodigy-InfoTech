# %% [markdown]
# <a href="https://colab.research.google.com/github/waqaskhaan/Machine-learning-tasks-Prodigy-InfoTech/blob/main/Internship%20task%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files
import io

# Upload the file
uploaded = files.upload()

# Load the dataset dynamically
for filename in uploaded.keys():
    df = pd.read_csv(io.BytesIO(uploaded[filename]))

# Display the first few rows of the dataframe to confirm successful loading
df.head()
# Out:
#      <input type="file" id="files-f3a2a97f-1b1b-4839-b27d-ad43900bef63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3a2a97f-1b1b-4839-b27d-ad43900bef63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display the first few rows of the dataframe
df.head()

# Display basic statistics
df.describe()

# Check for missing values
df.isnull().sum()

# Drop columns that are not needed for clustering (like CustomerID)
df.drop(['CustomerID'], axis=1, inplace=True)

# Encode categorical data (if any)
df = pd.get_dummies(df, drop_first=True)

# %%
# Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# Determine the optimal number of clusters using the elbow method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Plot the elbow method graph
plt.figure(figsize=(10, 5))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# From the elbow method, choose the optimal number of clusters (e.g., 5)
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# Add the cluster labels to the original dataframe
df['Cluster'] = clusters

# %%
# Plot the clusters (you can use different pairs of features to see the clusters)
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=df, palette='viridis')
plt.title('Clusters of Customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
# Analyze the clusters
cluster_summary = df.groupby('Cluster').mean()
print(cluster_summary)
# Out:
#                Age  Annual Income (k$)  Spending Score (1-100)  Gender_Male
# Cluster
# 0        32.692308           86.538462               82.128205     0.461538
# 1        36.482759           89.517241               18.000000     0.448276
# 2        49.813953           49.232558               40.069767     0.000000
# 3        24.907407           39.722222               61.203704     0.407407
# 4        55.714286           53.685714               36.771429     1.000000
